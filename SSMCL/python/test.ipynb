# %%
import sys
sys.path.append("/pscratch/sd/y/yuxihong/graphclustering/combblascorrect/SSMCL")
from pycombblas import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append("/pscratch/sd/y/yuxihong/graphclustering/combblascorrect/SSMCL")
# ----> 3 from pycombblas import *
#
# ImportError: /global/homes/y/yuxihong/miniconda3/lib/python3.11/site-packages/zmq/backend/cython/../../../../.././libgcc_s.so.1: version `GCC_12.0.0' not found (required by /opt/cray/pe/lib64/libmpi_gnu_123.so.12)
