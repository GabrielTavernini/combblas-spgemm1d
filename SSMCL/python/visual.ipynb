# %%
import numpy as np
from os.path import join
from fast_matrix_market import mmread
import matplotlib.pyplot as plt

# %%
chitu = "/home/hongy0a/graphclustering/dataset"
data = mmread(join(chitu, "1138_bus.mtx"))

# %%
plt.spy(data)
