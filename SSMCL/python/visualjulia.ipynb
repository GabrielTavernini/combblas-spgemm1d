# %%
using Plots 
using MatrixMarket

# %%
abspath = "/home/hongy0a/graphclustering/dataset/";
data = mmread(abspath * "vir_vs_vir_30_50length_propermm.mtx");

# %%
p = spy(data,grid = false, cbar = false,xticks = [], yticks = [],framestyle = :box,size=(400,400))
# savefig(p, "spy_plot.png")
